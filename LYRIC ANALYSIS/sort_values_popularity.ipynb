# %%
import pandas as pd

# %%
df = pd.read_csv('may_2024_pop_and_names_2025.csv')

# %%
df
# Out:
#         Unnamed: 0                track_id  \
# 0                0  3Vj8RQkFwOmDvUrwu6MtQZ
# 1                1  5jEtmndo1eO9yoKVSHvMpz
# 2                2  1YP7UWFugY2xRX3PdieTAs
# 3                3  1jt2raacDSDXbyN9o7NWcl
# 4                4  2TDgoPhthPcoy1mYcQxS8P
# ...            ...                     ...
# 198121      198121  4EdKJoJqBr73rA7aqrdBA5
# 198122      198122  3jdRcpohkvbG7WPo3mjiZD
# 198123      198123  0RMmzG0f5szIxC49oucu8w
# 198124      198124  3V0nnQhqvbE3JmiDdnzQFQ
# 198125      198125  34e2WyzmjG2aDk7KykOOZZ
#
#                                            track_name            artist_name  \
# 0       Yo Love - From "Queen & Slim: The Soundtrack"          Vince Staples
# 1                                           Hospedaje                  Sebas
# 2                               Himno de Fe y Alegría  Jairo y Su Barra Roja
# 3                                     Qué Bien Te Ves            Kexxy Pardo
# ...

# %%
df_sorted = df.sort_values(by='popularity_2024',ascending=False)

# %%
df_sorted.drop_duplicates(subset=['artist_name', 'track_name'], inplace=True)

# %%
df_sorted.head(50)
# Out:
#         Unnamed: 0                track_id                         track_name  \
# 101000      101000  1BxfuPKGuaTgP7aM0Bbdwr                       Cruel Summer
# 17310        17310  3U5JVgI2x4rDyHGObzJfNf                          Unwritten
# 76736        76736  7MXVkk9YMctZqd1Srtv4MB                            Starboy
# 56909        56909  1dGr1c8CrMLDpV6mPbImSI                              Lover
# 52855        52855  0VjIjW4GlUZAMYd2vXMi3b                    Blinding Lights
# 70773        70773  3hRV0jL3vUpRrcy398teAU                   The Night We Met
# 60573        60573  3JvKfv6T31zO0ini8iNItO                       Another Love
# 47179        47179  3AJwUDP919kvQ9QcozQPxg                             Yellow
# 50972        50972  2QjOHCTQ1Jl3zawyYOpxh6                    Sweater Weather
# 52953        52953  7qEHsqek33rTcFNT9PFqLf                  Someone You Loved
# 74226        74226  3xKsf9qdS1CyvXSMEid6g8                       Pink + White
# ...

# %%
df_sorted.to_csv('data_by_popular_M24.csv', index=False)  # index=False evita guardar el índice
