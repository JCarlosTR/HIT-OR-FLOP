# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
from spotipy.oauth2 import SpotifyOAuth
import requests
import pandas as pd
import numpy as np

# 🔹 Configurar credenciales de Spotify
client_id = "cb49cc625e6345c1a4414a0067fe80e2"
client_secret = "b7ab4bce9bcb481cb5e5b7cf7af58792"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
df_completo_cat = pd.read_csv("data_genres.csv")
df24 = pd.read_csv("datos/Mayo 2024 Indexar.csv")
df23 = pd.read_csv("datos/Junio 2023.csv")
df19 = pd.read_csv("datos/Abril 2019.csv")
df18 = pd.read_csv("datos/Noviembre 2018.csv")

# %%
df24
# Out:
#                       track_id                        album  popularity  \
# 0       6mICuAdrwEjh6Y6lroV2Kg                    El Dorado          78
# 1       7DM4BPaS7uofFul3ywMe46  Vente Pa' Ca (feat. Maluma)          72
# 2       3AEZUABDXNtecAOSC1qTfo                 Primera Cita          73
# 3       6rQSrBHf7HlZjtcMZ4S4bO                      Energía           0
# 4       58IL315gMSTD37DOZPJ2hf                  Shaky Shaky           0
# ...                        ...                          ...         ...
# 198121  6ulmtBYTYvfm1qySiZSeJq               Ay Marie Kondo           5
# 198122  6EZbksvLW7lykrFg6TkF76                     El Golpe           5
# 198123  3RZp1re0pT7Vh39GuD0q4m               Ya lo sabes EP          14
# 198124  1qhan4J1OXOd9f4caaTVqz               Ya lo sabes EP          21
# 198125  24yptNFNE9EiDZwOc4AyiN          Al Fin Pienso En Mi           0
#
#         duration_ms  explicit release_date  \
# 0            195840     False   2017-05-26
# ...

# %%
df24_filtered = df24.filter(['track_id', 'popularity'])

# %%
df_completo_cat
# Out:
#         acousticness                        artists  danceability  \
# 0           0.991000                    Mamie Smith         0.598
# 1           0.993000                    Mamie Smith         0.647
# 2           0.000173                Oscar Velazquez         0.730
# 3           0.295000                           Mixe         0.704
# 4           0.996000  Mamie Smith & Her Jazz Hounds         0.424
# ...              ...                            ...           ...
# 122216      0.009840                   Foo Fighters         0.530
# 122217      0.715000               Jazmine Sullivan         0.734
# 122218      0.000032                      Sean Paul         0.530
# 122219      0.105000                       Ashnikko         0.781
# 122220      0.795000                   Alessia Cara         0.429
#
#         duration_ms  energy  explicit                      id  \
# 0            168333   0.224         0  0cS0A1fUEUd1EW3FcF8AEI
# ...

# %%
df_index = pd.merge(df24_filtered, df_completo_cat, left_on='track_id', right_on='id')
df_index
# Out:
#                     track_id  popularity_x  acousticness           artists  \
# 0     3AEZUABDXNtecAOSC1qTfo            73        0.4000              CNCO
# 1     6DUdDIRgLqCGq1DwkNWQTN            80        0.1320            Maluma
# 2     1vvNmPOiUuyCbgWmtc6yfm            80        0.0935     Calvin Harris
# 3     6b8Be6ljOzmkOmFslEb23P            80        0.0340        Bruno Mars
# 4     5Fim1gaXBgsiFfsQAfQSDS            74        0.2820         Nicky Jam
# ...                      ...           ...           ...               ...
# 6105  6EJiVf7U0p1BBfs0qqeb1f            61        0.0135  Carly Rae Jepsen
# 6106  0INtJm8gCJKtNaAYQNVlpZ            69        0.0122         Dawn Penn
# 6107  7a9aeLVkn7DIqFjbanKz0k            56        0.3190       Hans Zimmer
# 6108  67HKtdqchK0rmODxsBeWT8            59        0.8130        Elton John
# 6109  6xkryXuiZU360Lngd4sx13            78        0.1390      Mariah Carey
#
# ...

# %%
df23_filtered = df23.filter(['track_id', 'popularity'])
df_index2 = pd.merge(df23_filtered, df_completo_cat, left_on='track_id', right_on='id')
df_index2
# Out:
#                     track_id  popularity_x  acousticness             artists  \
# 0     6lfxq3CG4xtTiEg7opyCyx            71        0.9050        Kina Grannis
# 1     5vjLSffimiIP26QG5WcN2K            82        0.4690    Chord Overstreet
# 2     1EzrEOXmMH3G43AXT1y7pA            80        0.5950          Jason Mraz
# 3     1KHdq8NK9QxnGjdXb55NiG            58        0.2000         Landon Pigg
# 4     3ILmwMefYZoQh5Cf5jeuUQ            61        0.0760       Motohiro Hata
# ...                      ...           ...           ...                 ...
# 6276  5pNavG44Qct8Vm5vQDDxYF            53        0.0984  for KING & COUNTRY
# 6277  3CO19cTl5zzlWx9GWEpOhD            53        0.1850    Michael W. Smith
# 6278  6jAAYLKxXPyeEoddXu6Gf7            50        0.3840  Tenth Avenue North
# 6279  7xzMrUmlooPa1Fmp88hlYc            59        0.8220       Cesária Evora
# 6280  2e6sXL2bYv4bSz6VTdnfLs            41        0.3810    Michael W. Smith
#
# ...

# %%
df19_filtered = df19.filter(['track_id', 'popularity'])
df_index3 = pd.merge(df19_filtered, df_completo_cat, left_on='track_id', right_on='id')
df_index3
# Out:
#                    track_id  popularity_x  acousticness  \
# 0    5H5izWjN7mkeMNwl9zJo9w            29        0.6240
# 1    4iOFENARPfS3d6P9rCQ2to            31        0.6030
# 2    6KCEUboGt4bvLwAqIJDuOA            28        0.4260
# 3    3DsGOzzGZYqEhtkkxlWNya            29        0.0961
# 4    1rz7pH66J1Fu6PRaMoAmFI            26        0.0950
# ..                      ...           ...           ...
# 722  2woGHWgrFfjXAgdUsitbqr            57        0.1620
# 723  2NTww3JSBHpySR2plYyAd6            54        0.6870
# 724  4qkVALwOxCIEZ7I5gkZ3m4            59        0.2550
# 725  7szRiHu6r91o2Po9GTPN4c            55        0.5680
# 726  4pbO4YIjnPtGJce4qlHSL6            55        0.1440
#
#                       artists  danceability  duration_ms  energy  explicit  \
# 0    Electric Light Orchestra         0.750       243867   0.796         0
# 1    Electric Light Orchestra         0.448       283400   0.882         0
# ...

# %%
df18_filtered = df18.filter(['track_id', 'popularity'])
df_index4 = pd.merge(df18_filtered, df_completo_cat, left_on='track_id', right_on='id')
df_index4
# Out:
#                    track_id  popularity_x  acousticness  \
# 0    5H5izWjN7mkeMNwl9zJo9w            35        0.6240
# 1    4iOFENARPfS3d6P9rCQ2to            29        0.6030
# 2    6KCEUboGt4bvLwAqIJDuOA            26        0.4260
# 3    3DsGOzzGZYqEhtkkxlWNya            28        0.0961
# 4    1rz7pH66J1Fu6PRaMoAmFI            25        0.0950
# ..                      ...           ...           ...
# 497  1BYZxKSf0aTxp8ZFoeyM3d            60        0.1130
# 498  467t3218y3yihFcyDGWjr0            53        0.5120
# 499  5VjTlCuX8C11QDunDwvyNh            57        0.7710
# 500  0TqaX16qLpX7YqFcAl9lDy            50        0.0589
# 501  1W4qc7UnAuRmT93W8Ad1t1            53        0.1740
#
#                       artists  danceability  duration_ms  energy  explicit  \
# 0    Electric Light Orchestra         0.750       243867   0.796         0
# 1    Electric Light Orchestra         0.448       283400   0.882         0
# ...

# %%
df_merged = df_index.merge(df_index2, on='track_id', suffixes=('_index', '_index2'))
df_merged = df_merged.merge(df_index3, on='track_id', suffixes=('', '_index3'))
df_merged = df_merged.merge(df_index4, on='track_id', suffixes=('', '_index4'))

df_merged
# Out:
#                    track_id  popularity_x_index  acousticness_index  \
# 0    4eWQlBRaTjPPUlzacqEeoQ                  75             0.18100
# 1    2RiBogNRfulkNf7fVbPOrJ                  72             0.48400
# 2    5GKwq4sO5ZHKuWaDmdwMQc                  72             0.19100
# 3    2xLMifQCjDGFmkHkpNLD9h                  84             0.00513
# 4    2xLMifQCjDGFmkHkpNLD9h                  84             0.00513
# ..                      ...                 ...                 ...
# 121  37mfTcSlX60JtAvAETytGs                  70             0.00139
# 122  1i36kkhmhBxf4lYJscg5zK                  68             0.15400
# 123  1i36kkhmhBxf4lYJscg5zK                  68             0.15400
# 124  01TyFEZu6mHbffsVfxgrFn                  40             0.67400
# 125  01TyFEZu6mHbffsVfxgrFn                  40             0.67400
#
#                          artists_index  danceability_index  duration_ms_index  \
# ...

# %%
num_hits = df_completo_cat[df_completo_cat['popularity_cat'] == 'HIT'].shape[0]
print(num_hits)
# Out:
# 276

# %%
# ID del track que quieres obtener
track_id = '3n3Ppam7vgaVa1iaRUc9Lp'  # Reemplaza con el ID del track que desees

# Obtener información del track
track_info = sp.track(track_id)

# Extraer la información deseada
track_data = {
    'id': track_info['id'],
    'name': track_info['name'],
    'popularity': track_info['popularity'],
    'artists': [{'name': artist['name'], 'id': artist['id']} for artist in track_info['artists']]
}

print(track_data)
