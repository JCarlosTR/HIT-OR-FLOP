# %%
# prompt: montar el drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/PROY 3

#df_prev = pd.read_csv("minable_view.csv")
df = pd.read_csv("minable_view_w_imputed_genres.csv")
# Out:
# /content/drive/MyDrive/Colab Notebooks/PROY 3

# %%
# Previous dataset without genres
#df_prev
# Out:
#                             id  \
# 0       0cS0A1fUEUd1EW3FcF8AEI
# 1       11m7laMUgmOKqI3oYzuhne
# 2       19Lc5SfJJ5O1oaxY0fpwfh
# 3       2hJjbsLCytGsnAHfdsLejp
# 4       3HnrHGLE9u2MjHtdobfWl9
# ...                        ...
# 280448  4NqQaovM14WR2hNPMFxgjb
# 280449  3bkkMZEAhx7rTVz1C0itRQ
# 280450  0IGxkEgMeF1dwOSIj2IUrT
# 280451  5UusfWUMMLEXLMc1ViNZoe
# 280452  3NUmUIyzNLBp8bCFMH8Mif
#
#                                                track_name  \
# 0                                Keep A Song In Your Soul
# 1                                            Golfing Papa
# 2       True House Music - Xavier Santos & Carlos Gomi...
# 3                                               Xuniverxe
# 4                             Crazy Blues - 78rpm Version
# ...                                                   ...
# 280448                                               25/8
# 280449                                         Black Swan
# 280450                                             Crisis
# 280451                                              @ MEH
# 280452                                   Waiting On A War
#
#                           artist_name  new_popularity_2025  acousticness  \
# 0                         Mamie Smith                   18      0.991000
# 1                         Mamie Smith                    1      0.993000
# 2                     Oscar Velazquez                   13      0.000173
# 3                        Mikesmooveee                    0      0.295000
# 4       Mamie Smith & Her Jazz Hounds                    3      0.996000
# ...                               ...                  ...           ...
# 280448                      Bad Bunny                   70      0.092000
# 280449                            BTS                    0      0.137000
# 280450                         Jasiah                   48      0.263000
# 280451                  Playboi Carti                   59      0.013600
# 280452                   Foo Fighters                    0      0.009840
#
#         danceability  duration_ms  energy  explicit  instrumentalness  ...  \
# 0              0.598       168333   0.224         0          0.000522  ...
# 1              0.647       163827   0.186         0          0.000018  ...
# 2              0.730       422087   0.798         0          0.801000  ...
# 3              0.704       165224   0.707         1          0.000246  ...
# 4              0.424       198627   0.245         0          0.799000  ...
# ...              ...          ...     ...       ...               ...  ...
# 280448         0.761       243276   0.732         0          0.000000  ...
# 280449         0.719       198261   0.758         0          0.000000  ...
# 280450         0.760       109595   0.794         1          0.003240  ...
# 280451         0.876       166799   0.492         1          0.000283  ...
# 280452         0.530       253840   0.759         0          0.000000  ...
#
#         duration_cat  key_cat  imputed_date_cat  mode_cat  year_cat  \
# 0                Mid        F               Yes     Minor       20s
# 1                Mid        C               Yes     Major       20s
# 2              Large        D                No     Major       20s
# 3                Mid    A♯/B♭                No     Minor       20s
# 4                Mid        F               Yes     Major       20s
# ...              ...      ...               ...       ...       ...
# 280448           Mid        E                No     Minor     2020s
# 280449           Mid        D                No     Minor     2020s
# 280450         Short    A♯/B♭                No     Minor     2020s
# 280451           Mid        B                No     Minor     2020s
# 280452           Mid        G                No     Major     2020s
#
#        genres_from_artists_cat  popularity_2025_cat    album  popularity_2024  \
# 0                          Yes                 FLOP  unknown               -1
# 1                           No                 FLOP  unknown               -1
# 2                          Yes                 FLOP  unknown               -1
# 3                          Yes                 FLOP  unknown               -1
# 4                           No                 FLOP  unknown               -1
# ...                        ...                  ...      ...              ...
# 280448                      No              MID-HIT  unknown               70
# 280449                      No                 FLOP  unknown                0
# 280450                     Yes                  MID  unknown               52
# 280451                      No              MID-HIT  unknown               60
# 280452                      No                 FLOP  unknown                0
#
#         popularity_2024_cat
# 0                   unknown
# 1                   unknown
# 2                   unknown
# 3                   unknown
# 4                   unknown
# ...                     ...
# 280448              MID-HIT
# 280449                 FLOP
# 280450              MID-HIT
# 280451              MID-HIT
# 280452                 FLOP
#
# [280453 rows x 48 columns]

# %%
df
# Out:
#                             id  \
# 0       0cS0A1fUEUd1EW3FcF8AEI
# 1       11m7laMUgmOKqI3oYzuhne
# 2       19Lc5SfJJ5O1oaxY0fpwfh
# 3       2hJjbsLCytGsnAHfdsLejp
# 4       3HnrHGLE9u2MjHtdobfWl9
# ...                        ...
# 280448  4NqQaovM14WR2hNPMFxgjb
# 280449  3bkkMZEAhx7rTVz1C0itRQ
# 280450  0IGxkEgMeF1dwOSIj2IUrT
# 280451  5UusfWUMMLEXLMc1ViNZoe
# 280452  3NUmUIyzNLBp8bCFMH8Mif
#
#                                                track_name  \
# 0                                Keep A Song In Your Soul
# 1                                            Golfing Papa
# 2       True House Music - Xavier Santos & Carlos Gomi...
# 3                                               Xuniverxe
# 4                             Crazy Blues - 78rpm Version
# ...                                                   ...
# 280448                                               25/8
# 280449                                         Black Swan
# 280450                                             Crisis
# 280451                                              @ MEH
# 280452                                   Waiting On A War
#
#                           artist_name  new_popularity_2025  acousticness  \
# 0                         Mamie Smith                   18      0.991000
# 1                         Mamie Smith                    1      0.993000
# 2                     Oscar Velazquez                   13      0.000173
# 3                        Mikesmooveee                    0      0.295000
# 4       Mamie Smith & Her Jazz Hounds                    3      0.996000
# ...                               ...                  ...           ...
# 280448                      Bad Bunny                   70      0.092000
# 280449                            BTS                    0      0.137000
# 280450                         Jasiah                   48      0.263000
# 280451                  Playboi Carti                   59      0.013600
# 280452                   Foo Fighters                    0      0.009840
#
#         danceability  duration_ms  energy  explicit  instrumentalness  ...  \
# 0              0.598       168333   0.224         0          0.000522  ...
# 1              0.647       163827   0.186         0          0.000018  ...
# 2              0.730       422087   0.798         0          0.801000  ...
# 3              0.704       165224   0.707         1          0.000246  ...
# 4              0.424       198627   0.245         0          0.799000  ...
# ...              ...          ...     ...       ...               ...  ...
# 280448         0.761       243276   0.732         0          0.000000  ...
# 280449         0.719       198261   0.758         0          0.000000  ...
# 280450         0.760       109595   0.794         1          0.003240  ...
# 280451         0.876       166799   0.492         1          0.000283  ...
# 280452         0.530       253840   0.759         0          0.000000  ...
#
#         popularity_2024  popularity_2024_cat  month  dayofweek  month_sin  \
# 0                    -1              unknown    1.0        3.0   0.500000
# 1                    -1              unknown    1.0        3.0   0.500000
# 2                    -1              unknown    1.0        3.0   0.500000
# 3                    -1              unknown   10.0        4.0  -0.866025
# 4                    -1              unknown    1.0        3.0   0.500000
# ...                 ...                  ...    ...        ...        ...
# 280448               70              MID-HIT    2.0        4.0   0.866025
# 280449                0                 FLOP    2.0        4.0   0.866025
# 280450               52              MID-HIT    7.0        0.0  -0.500000
# 280451               60              MID-HIT    4.0        3.0   0.866025
# 280452                0                 FLOP    1.0        3.0   0.500000
#
#        month_cos  dayofweek_sin  dayofweek_cos  imputed_genre  confidence
# 0       0.866025       0.433884      -0.900969   not required    0.000000
# 1       0.866025       0.433884      -0.900969   not required    0.000000
# 2       0.866025       0.433884      -0.900969   not required    0.000000
# 3       0.500000      -0.433884      -0.900969           rock    0.223333
# 4       0.866025       0.433884      -0.900969           jazz    0.633333
# ...          ...            ...            ...            ...         ...
# 280448  0.500000      -0.433884      -0.900969   not required    0.000000
# 280449  0.500000      -0.433884      -0.900969   not required    0.000000
# 280450 -0.866025       0.000000       1.000000            rap    0.420000
# 280451 -0.500000       0.433884      -0.900969   not required    0.000000
# 280452  0.866025       0.433884      -0.900969   not required    0.000000
#
# [280453 rows x 56 columns]

# %%
df.isna().any()
# Out:
# id                         False
# track_name                  True
# artist_name                 True
# new_popularity_2025        False
# acousticness               False
# danceability               False
# duration_ms                False
# energy                     False
# explicit                   False
# instrumentalness           False
# key                        False
# liveness                   False
# loudness                   False
# mode                       False
# popularity_2021            False
# release_date                True
# speechiness                False
# tempo                      False
# valence                    False
# year                        True
# genres                     False
# main_genre                 False
# subgenre_1                  True
# subgenre_2                  True
# genres_artists             False
# acousticness_cat           False
# danceability_cat           False
# energy_cat                 False
# explicit_cat               False
# instrumentalness_cat       False
# liveness_cat               False
# loudness_cat               False
# speechiness_cat            False
# tempo_cat                  False
# valence_cat                False
# month_cat                   True
# featuring_cat              False
# popularity_2021_cat        False
# duration_cat                True
# key_cat                    False
# imputed_date_cat           False
# mode_cat                   False
# year_cat                   False
# genres_from_artists_cat    False
# popularity_2025_cat        False
# album                       True
# popularity_2024            False
# popularity_2024_cat        False
# month                       True
# dayofweek                   True
# month_sin                   True
# month_cos                   True
# dayofweek_sin               True
# dayofweek_cos               True
# imputed_genre              False
# confidence                 False
# dtype: bool

# %%
def season(month):
    if month in [12,1,2]:
        return 'Winter'
    elif month in [3,4,5]:
        return 'Spring'
    elif month in [6,7,8]:
        return 'Summer'
    else:
        return 'Autumn'

# %%
df["release_date"] = pd.to_datetime(
    df["release_date"], format="%Y-%m-%d", errors="coerce"
)

df["month"] = df["release_date"].dt.month
df["dayofweek"] = df["release_date"].dt.dayofweek

df["month_sin"] = np.sin(2 * np.pi * df["month"] / 12)
df["month_cos"] = np.cos(2 * np.pi * df["month"] / 12)

df["dayofweek_sin"] = np.sin(2 * np.pi * df["dayofweek"] / 7)
df["dayofweek_cos"] = np.cos(2 * np.pi * df["dayofweek"] / 7)

df["is_weekend"] = df["dayofweek"].isin([5, 6])

df["season"] = df["month"].apply(season)

df['years_since_release'] = 2025 - df['year']

df['is_positive_mood'] = df['valence'] > 0.7

df['has_lyrics'] = df['speechiness'] > 0.33

df['is_loud'] = df['loudness'] > -6

df['is_live'] = df['liveness'] > 0.8

df['is_common_key'] = df['key'].isin([0,2,5,7])

df['is_instrumental'] = df['instrumentalness'] > 0.7

df['is_energetic'] = df['energy'] > 0.75

df['is_duration_friendly'] = df['duration_ms'].between(120000, 240000)

df['is_danceable'] = df['danceability'] > 0.6

df['is_acoustic'] = df['acousticness'] > 0.8

df['energy_valence'] = df['energy'] * df['valence']

df['speechiness_explicit'] = df['speechiness'] * df['explicit']

df['danceability_tempo'] = df['danceability'] * df['tempo']

df.drop(["release_date", "month", "dayofweek"], axis=1, inplace=True)

# %%
df.to_csv('minable_view_post.csv', index=False)

# %%
df
# Out:
#                             id  \
# 0       0cS0A1fUEUd1EW3FcF8AEI
# 1       11m7laMUgmOKqI3oYzuhne
# 2       19Lc5SfJJ5O1oaxY0fpwfh
# 3       2hJjbsLCytGsnAHfdsLejp
# 4       3HnrHGLE9u2MjHtdobfWl9
# ...                        ...
# 280448  4NqQaovM14WR2hNPMFxgjb
# 280449  3bkkMZEAhx7rTVz1C0itRQ
# 280450  0IGxkEgMeF1dwOSIj2IUrT
# 280451  5UusfWUMMLEXLMc1ViNZoe
# 280452  3NUmUIyzNLBp8bCFMH8Mif
#
#                                                track_name  \
# 0                                Keep A Song In Your Soul
# 1                                            Golfing Papa
# 2       True House Music - Xavier Santos & Carlos Gomi...
# 3                                               Xuniverxe
# 4                             Crazy Blues - 78rpm Version
# ...                                                   ...
# 280448                                               25/8
# 280449                                         Black Swan
# 280450                                             Crisis
# 280451                                              @ MEH
# 280452                                   Waiting On A War
#
#                           artist_name  new_popularity_2025  acousticness  \
# 0                         Mamie Smith                   18      0.991000
# 1                         Mamie Smith                    1      0.993000
# 2                     Oscar Velazquez                   13      0.000173
# 3                        Mikesmooveee                    0      0.295000
# 4       Mamie Smith & Her Jazz Hounds                    3      0.996000
# ...                               ...                  ...           ...
# 280448                      Bad Bunny                   70      0.092000
# 280449                            BTS                    0      0.137000
# 280450                         Jasiah                   48      0.263000
# 280451                  Playboi Carti                   59      0.013600
# 280452                   Foo Fighters                    0      0.009840
#
#         danceability  duration_ms  energy  explicit  instrumentalness  ...  \
# 0              0.598       168333   0.224         0          0.000522  ...
# 1              0.647       163827   0.186         0          0.000018  ...
# 2              0.730       422087   0.798         0          0.801000  ...
# 3              0.704       165224   0.707         1          0.000246  ...
# 4              0.424       198627   0.245         0          0.799000  ...
# ...              ...          ...     ...       ...               ...  ...
# 280448         0.761       243276   0.732         0          0.000000  ...
# 280449         0.719       198261   0.758         0          0.000000  ...
# 280450         0.760       109595   0.794         1          0.003240  ...
# 280451         0.876       166799   0.492         1          0.000283  ...
# 280452         0.530       253840   0.759         0          0.000000  ...
#
#         is_live  is_common_key  is_instrumental  is_energetic  \
# 0         False           True            False         False
# 1         False           True            False         False
# 2         False           True             True          True
# 3         False          False            False         False
# 4         False           True             True         False
# ...         ...            ...              ...           ...
# 280448    False          False            False         False
# 280449    False           True            False          True
# 280450    False          False            False          True
# 280451    False          False            False         False
# 280452    False           True            False          True
#
#         is_duration_friendly  is_danceable  is_acoustic  energy_valence  \
# 0                       True         False         True        0.142016
# 1                       True          True         True        0.128154
# 2                      False          True        False        0.033676
# 3                       True          True        False        0.211393
# 4                       True         False         True        0.116865
# ...                      ...           ...          ...             ...
# 280448                 False          True        False        0.396744
# 280449                  True          True        False        0.371420
# 280450                 False          True        False        0.462902
# 280451                  True          True        False        0.196800
# 280452                 False         False        False        0.381018
#
#         speechiness_explicit danceability_tempo
# 0                     0.0000          89.685648
# 1                     0.0000          63.147200
# 2                     0.0000          93.437810
# 3                     0.0768          85.941504
# 4                     0.0000          44.040880
# ...                      ...                ...
# 280448                0.0000         115.658302
# 280449                0.0000         105.709537
# 280450                0.3440         126.152400
# 280451                0.1530         132.314544
# 280452                0.0000          69.959470
#
# [280453 rows x 69 columns]
